# %% [markdown]
# # title

# %% [markdown]
# ## Here we have some text

# %% [markdown]
# * we have some code here
# * and we want to run it in a jupyter notebook
# * so we can see the output

# %%
result = 1 + 1
result
# Out:
# 2
